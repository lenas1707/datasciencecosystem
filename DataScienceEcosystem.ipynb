# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:d10709cd-6281-47b1-8ee5-5f5f6dd5206f.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro.png](attachment:fdff00cb-6b46-47ac-9cd1-5a9595e3aa13.png)

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science.
# - Identify commonly used libraries in Data Science.
# - Explore open-source tools for development environments in Data Science.
# - Demonstrate examples of arithmetic expressions in Python.
# - Convert time units using Python expressions.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Java

# %% [markdown]
# ![4-dslanguages.png](attachment:b8c9b56d-c0e8-4d33-98b5-49c508ef896c.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# ![5-dslibraries.png](attachment:bc7ac16b-8452-4729-9101-ecaccfa1abaf.png)

# %% [markdown]
# | Data Science Tools |
# |-------------------|
# | Jupyter Notebook  |
# | RStudio           |
# | Apache Spark      |

# %% [markdown]
# ![6-dstools.png](attachment:b4d1387f-55f9-4ee8-a5f8-0dc383421511.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:e5f90c3b-13e1-4bce-9da4-52442f582603.png)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:1462045c-a86f-4134-ba18-d78f83098e01.png)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:36c7d2d6-9e9d-458f-8802-211c4ba446ce.png)

# %% [markdown]
# ## Author
# Leonardo
